# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1.25,1.11,2.08,1.7,1.67,5.26,7.14,16.7,5,16.7,0.1,25]

y=[0.3135,0.2323,0.5948,0.4976,0.4873,0.8380,0.8794,0.9508,0.8247,0.9482,0.9147,0.9625]


x=[6,12,18,24,30,36,42,48]
y1=[1,1,1,1,1,1,1,1]
y2=[0.875,0.78,0.77,0.76,0.75,0.75,0.74,0.74]
y3=[0.5,0.1,0.11,0.12,0.1,0.09,0.1,0.09]

# %%
pickle.dump(batches, open('BatchData/' +outfile+ 'Data.seqs', 'wb'), -1)

# %%
x.sort()
y.sort(reverse=True)
plt.grid()
plt.xlabel('Hours')
plt.ylabel('Missing rate')
plt.plot(x, y, marker='o')
plt.savefig('mimiciii_missing_rate.jpg', dpi=300)
plt.show()

# %%
x=[6,12,18,24,30,36,42,48]
y1=[1,1,1,1,1,1,1,1]
y2=[0.875,0.78,0.77,0.76,0.75,0.75,0.74,0.74]
y3=[0.5,0.1,0.11,0.12,0.1,0.09,0.1,0.09]
plt.grid()
plt.xlabel('Hours')
plt.ylabel('Missing rate')
plt.plot(x, y1, marker='o',label='max')
plt.plot(x, y2, marker='o',label='avg')
plt.plot(x, y3, marker='o',label='min')
plt.legend(loc='lower right')
plt.savefig('pysionet_missing_rate.jpg', dpi=300)
plt.show()

# %%
x=[1,2,3,4,5,6]
y1=[0.033,0.018,0.017,0.017,0.016,0.015]

plt.grid()
plt.xlabel('Hours')
plt.ylabel('Missing rate')
plt.plot(x, y1, marker='o')

plt.savefig('sepsis_missing_rate.jpg', dpi=300)
plt.show()
